# %%
import pandas as pd

# %%
df = pd.read_parquet("./pixel_parquet/savi_20211107.parquet")

# %%
len(df)
# Out:
# 10986959

# %%
df
# Out:
#             pixel_id   row    col        date   value raster_type  \
# 0           319_1049   319   1049  2021-11-07  0.4079        savi
# 1           319_1050   319   1050  2021-11-07  0.3972        savi
# 2           320_1049   320   1049  2021-11-07  0.3840        savi
# 3           320_1050   320   1050  2021-11-07  0.3656        savi
# 4           321_1049   321   1049  2021-11-07  0.3797        savi
# ...              ...   ...    ...         ...     ...         ...
# 10986954  7396_11898  7396  11898  2021-11-07  0.4465        savi
# 10986955  7396_11899  7396  11899  2021-11-07  0.4028        savi
# 10986956  7397_11897  7397  11897  2021-11-07  0.4345        savi
# 10986957  7397_11898  7397  11898  2021-11-07  0.4362        savi
# 10986958  7397_11899  7397  11899  2021-11-07  0.4079        savi
#
#                 raster_file
# 0         savi_20211107.tif
# 1         savi_20211107.tif
# 2         savi_20211107.tif
# 3         savi_20211107.tif
# ...
